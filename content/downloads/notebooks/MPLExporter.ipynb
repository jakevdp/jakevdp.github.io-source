# %% [markdown]
# # mplexporter

# %% [markdown]
# blah

# %% [markdown]
# ## matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 10, 50)
y = np.sin(x)
y2 = np.random.normal(y, 0.3)
plt.plot(x, y)
plt.plot(x, y2, 'ok');

# %%
from mplexporter.renderers.vega_renderer import fig_to_vega
fig_to_vega(fig, notebook=False)
# Out:
# '<div id="vis22300"></div><script>\n\n( function() {\n  var _do_plot = function() {\n    if ( (typeof vg == \'undefined\') && (typeof IPython != \'undefined\')) {\n      $([IPython.events]).on("vega_loaded.vincent", _do_plot);\n      return;\n    }\n    vg.parse.spec({"width": 480, "scales": [{"range": "width", "type": "linear", "domain": [0.0, 10.0], "name": "x"}, {"range": "height", "type": "linear", "domain": [-1.5, 1.5], "name": "y"}], "marks": [{"from": {"data": "table001"}, "type": "line", "properties": {"enter": {"strokeWidth": {"value": 1.0}, "strokeOpacity": {"value": 1}, "stroke": {"value": "#0000FF"}, "interpolate": {"value": "monotone"}, "y": {"field": "data.y", "scale": "y"}, "x": {"field": "data.x", "scale": "x"}}}}, {"from": {"data": "table002"}, "type": "symbol", "properties": {"enter": {"stroke": {"value": "#000000"}, "strokeWidth": {"value": 0.5}, "fillOpacity": {"value": 1}, "y": {"field": "data.y", "scale": "y"}, "x": {"field": "data.x", "scale": "x"}, "strokeOpac
# ...
